# %%
# kaggle house price

# %%
# %matplotlib inline
import d2lzh as d2l
from mxnet import autograd, gluon, init, nd
from mxnet.gluon import data as gdata, loss as gloss, nn
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv('F:/Downloads/train.csv')
test_data = pd.read_csv('F:/Downloads/test.csv')

# %%
all_features = pd.concat((train_data.iloc[:, 1:-1], test_data.iloc[:, 1:]))

# %%
# 连续值的预处理 将连续数值的特征进行标准化 缺失的特征用均值代替
numeric_features = all_features.dtypes[all_features.dtypes != 'object'].index
all_features[numeric_features] = all_features[numeric_features].apply(
    lambda x: (x - x.mean()) / (x.std()))
all_features[numeric_features] = all_features[numeric_features].fillna(0)

# %%
# 离散特征转换为 指示特征 缺失值也作为合法特征
all_features = pd.get_dummies(all_features, dummy_na=True)

# %%
n_train = train_data.shape[0]
train_features = nd.array(all_features[:n_train].values)
test_features = nd.array(all_features[n_train:].values)
train_labels = nd.array(train_data.SalePrice.values).reshape((-1, 1))

# %%
# 训练模型
loss = gloss.L2Loss()

def get_net():
    net = nn.Sequential()
    net.add(nn.Dense(256, activation='relu'),
            nn.Dropout(0.5),
            nn.Dense(128, activation='relu'),
            nn.Dropout(0.3),
            nn.Dense(1))
    net.initialize()

    return net

# %%
def log_rmse(net, features, labels):
    clipped_preds = nd.clip(net(features), 1, float('inf'))
    rmse = nd.sqrt(2 * loss(clipped_preds.log(), labels.log()).mean())
    
    return rmse.asscalar()

# %%
def train(net, train_features, train_labels, test_featues, test_labels, 
            num_epochs, lr, wd, batch_size):
    train_ls, test_ls = [], []
    train_iter = gdata.DataLoader(gdata.ArrayDataset(
        train_features, train_labels), batch_size, shuffle=True)

    trainer = gluon.Trainer(net.collect_params(), 'adam', {
        'learning_rate': lr, 'wd': wd
    })

    for epoch in range(num_epochs):
        for X, y in train_iter:
            with autograd.record():
                l = loss(net(X), y)
            l.backward()
            trainer.step(batch_size)

        train_ls.append(log_rmse(net, train_features, train_labels))
        if test_labels is not None:
            test_ls.append(log_rmse(net, test_featues, test_labels))

    return train_ls, test_ls

# %%
def get_k_fold_data(k, i, X, y):
    assert k > 1
    fold_size = X.shape[0] // k
    X_train, y_train = None, None
    for j in range(k):
        idx = slice(j * fold_size, (j + 1) * fold_size)
        X_part, y_part = X[idx, :], y[idx]

        if j == i:
            X_vaild, y_valid = X_part, y_part
        # 这里是组装所选取的验证集之外的k-1折形成训练集
        elif X_train is None:
            X_train, y_train = X_part, y_part
        else:
            X_train = nd.concat(X_train, X_part, dim=0)
            y_train = nd.concat(y_train, y_part, dim=0)

    return X_train, y_train, X_vaild, y_valid

# %%
# 训练k次
def k_fold(k, X_train, y_train, num_epochs, lr, wd, batch_size):
    train_l_sum, valid_l_sum = 0, 0
    for i in range(k):
        # 这个里面会 训练出 k个net ?
        data = get_k_fold_data(k, i, X_train, y_train)
        net = get_net()
        train_ls, valid_ls = train(net, *data, num_epochs, lr, wd, batch_size)

        train_l_sum += train_ls[-1]
        valid_l_sum += valid_ls[-1]

        # 这里应该是选择了其中训练的一折来作图
        if 0 == i:
            d2l.semilogy(range(1, num_epochs + 1), train_ls, 'epochs', 'rmse',
            range(1, num_epochs + 1), valid_ls, ['train', 'valid'])
        
        print('fold %d, train rmse %f, valid rmse %f' %
                (i, train_ls[-1], valid_ls[-1]))

    return train_l_sum / k, valid_l_sum / k

# %%
k, num_epochs, lr, wd, batch_size = 5, 350, 1.5, 0, 64
train_l, valid_l = k_fold(k, train_features, train_labels, num_epochs, lr, wd, batch_size)

print('%d-fold validation: avg train rmse %f, avg valid rmse %f' % (k, train_l, valid_l))
# Out:
# fold 0, train rmse 0.850350, valid rmse 0.862654
# fold 1, train rmse 0.701065, valid rmse 0.723071
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-d98b053174ee> in <module>
#       1 k, num_epochs, lr, wd, batch_size = 5, 350, 1.5, 0, 64
# ----> 2 train_l, valid_l = k_fold(k, train_features, train_labels, num_epochs, lr, wd, batch_size)
#       3
#       4 print('%d-fold validation: avg train rmse %f, avg valid rmse %f' % (k, train_l, valid_l))
#
# <ipython-input-27-22b3db7f3205> in k_fold(k, X_train, y_train, num_epochs, lr, wd, batch_size)
#       6         data = get_k_fold_data(k, i, X_train, y_train)
#       7         net = get_net()
# ----> 8         train_ls, valid_ls = train(net, *data, num_epochs, lr, wd, batch_size)
#       9
#      10         train_l_sum += train_ls[-1]
#
# <ipython-input-26-6c5fafea91c3> in train(net, train_features, train_labels, test_featues, test_labels, num_epochs, lr, wd, batch_size)
#      10
#      11     for epoch in range(num_epochs):
# ---> 12         for X, y in train_iter:
#      13             with autograd.record():
#      14                 l = loss(net(X), y)
#
# E:\Anaconda3\envs\gluon\lib\site-packages\mxnet\gluon\data\dataloader.py in same_process_iter()
#     573             def same_process_iter():
#     574                 for batch in self._batch_sampler:
# --> 575                     ret = self._batchify_fn([self._dataset[idx] for idx in batch])
#     576                     if self._pin_memory:
#     577                         ret = _as_in_context(ret, context.cpu_pinned(self._pin_device_id))
#
# E:\Anaconda3\envs\gluon\lib\site-packages\mxnet\gluon\data\dataloader.py in <listcomp>(.0)
#     573             def same_process_iter():
#     574                 for batch in self._batch_sampler:
# --> 575                     ret = self._batchify_fn([self._dataset[idx] for idx in batch])
#     576                     if self._pin_memory:
#     577                         ret = _as_in_context(ret, context.cpu_pinned(self._pin_device_id))
#
# E:\Anaconda3\envs\gluon\lib\site-packages\mxnet\gluon\data\dataset.py in __getitem__(self, idx)
#     163             return self._data[0][idx]
#     164         else:
# --> 165             return tuple(data[idx] for data in self._data)
#     166
#     167     def __len__(self):
#
# E:\Anaconda3\envs\gluon\lib\site-packages\mxnet\gluon\data\dataset.py in <genexpr>(.0)
#     163             return self._data[0][idx]
#     164         else:
# --> 165             return tuple(data[idx] for data in self._data)
#     166
#     167     def __len__(self):
#
# E:\Anaconda3\envs\gluon\lib\site-packages\mxnet\ndarray\ndarray.py in __getitem__(self, key)
#     509         indexing_dispatch_code = _get_indexing_dispatch_code(key)
#     510         if indexing_dispatch_code == _NDARRAY_BASIC_INDEXING:
# --> 511             return self._get_nd_basic_indexing(key)
#     512         elif indexing_dispatch_code == _NDARRAY_ADVANCED_INDEXING:
#     513             return self._get_nd_advanced_indexing(key)
#
# E:\Anaconda3\envs\gluon\lib\site-packages\mxnet\ndarray\ndarray.py in _get_nd_basic_indexing(self, key)
#     783                     'index {} is out of bounds for axis 0 with size {}'.format(
#     784                         key, shape[0]))
# --> 785             return self._at(key)
#     786         elif isinstance(key, py_slice):
#     787             if key.step is not None and key.step != 1:
#
# E:\Anaconda3\envs\gluon\lib\site-packages\mxnet\ndarray\ndarray.py in _at(self, idx)
#     942                                  % (idx-length, length))
#     943         check_call(_LIB.MXNDArrayAt(
# --> 944             self.handle, mx_uint(idx), ctypes.byref(handle)))
#     945         return NDArray(handle=handle, writable=self.writable)
#     946
#
# KeyboardInterrupt:

# %%
def train_and_pred(train_features, test_features, train_labels, test_data, num_epochs, lr,
                        wd, batch_size):
    net = get_net()
    train_ls, _ = train(net, train_features, train_labels, None, None, 
                            num_epochs, lr, wd, batch_size)
    d2l.semilogy(range(1, num_epochs+1), train_ls, 'epochs', 'rmse')
    print('train rmse %f' % train_ls[-1])
    preds = net(test_features).asnumpy()
    test_data['SalePrice'] = pd.Series(preds.reshape((1, -1))[0])
    submission = pd.concat([test_data['Id'], test_data['SalePrice']], axis=1)
    submission.to_csv('./Res/house-price-sub.csv', index=False)

# %%
train_and_pred(train_features, test_features, train_labels, test_data, num_epochs, lr, wd,
batch_size)
# Out:
# train rmse 0.016521

# %%
# help(pd.get_dummies)
